# %% [markdown]
# # NAME-KUMKUM GEHLOT
# # OBJECT DETECTION PROJECT

# %%
import os
os.sys.path
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 import os
#       2 os.sys.path
# ----> 3 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import matplotlib.pyplot as plt

# %%
config_file = 'ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt'
frozen_model = 'frozen_inference_graph.pb'

# %%
model = cv2.dnn_DetectionModel(frozen_model,config_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model = cv2.dnn_DetectionModel(frozen_model,config_file)
#
# NameError: name 'cv2' is not defined

# %%
classLables = [] #empty list of python
file_name= 'Lables.txt
with open(file_name,'rt') as fpt:
    classLables = fpt.read().rstrip('\n').split('\n')
    #classLables.append(fpt.read())
# Out:
#   Cell In[8], line 2
#     file_name= 'Lables.txt
#                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
print(classLables)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(classLables)
#
# NameError: name 'classLables' is not defined

# %%
print(len(classLables))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(len(classLables))
#
# NameError: name 'classLables' is not defined

# %%
model.setInputSize(320,320)
model.setInputScale(1.0/127.5) ## 255/2=127.5
model.setInputMean((127.5,127.5,127.5)) ## mobilnet => [-1,1]
model.setInputSwapRB(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.setInputSize(320,320)
#       2 model.setInputScale(1.0/127.5) ## 255/2=127.5
#       3 model.setInputMean((127.5,127.5,127.5)) ## mobilnet => [-1,1]
#
# NameError: name 'model' is not defined

# %% [markdown]
#     ## Read an image

# %%
img = cv2.imread('2.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 img = cv2.imread('2.jpg')
#
# NameError: name 'cv2' is not defined

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
ClassIndex , confidece, bbox = model.detect(img, confThreshold=0.5)

# %%
print(ClassIndex)
# Out:
# [1 3 3]

# %%
font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN
for ClassInd, conf, boxes in zip(ClassIndex.flatten(), confidece.flatten(), bbox):
    #cv2.rectangle(frame, (x,y),(x+w , y+h),(255,0,0),2)
    #cv2.putText(img, text, (text_offset_x, text_offset_y), font, fontScale = font_scale, color = (0,0,0), thickness=1)
    cv2.rectangle(img, boxes,(255, 0, 0), 2)
    cv2.putText(img, classLables[ClassInd-1] , (boxes[0]+10,boxes[1]+40) , font, fontScale = font_scale, color = (0,255,0), thickness=3)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.show()

# %%
detected_objects = [] 
# Perform object detection
if img is not None:
    ClassIndex, confidence, bbox = model.detect(img, confThreshold=0.5)

    # Display the annotated image
    font_scale = 3
    font = cv2.FONT_HERSHEY_PLAIN
    for ClassInd, conf, boxes in zip(ClassIndex.flatten(), confidence.flatten(), bbox):
        # Get the class name using the ClassInd
        class_name = class_labels[ClassInd - 1]
        detected_objects.append(class_name)
        
        # Draw bounding box and label with class name
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()
print("Detected objects:")
for obj in detected_objects:
    print(obj)
# Out:
# Detected objects:
# person
